# %% [markdown]
# # Overview of all Features Extractions

# %%
from utils_lib.utils import Utils
import time
import torch
import torch.nn as nn
import random
import numpy as np
import matplotlib.pyplot as plt

utils = Utils()

import utils_lib.feature_extractor_layers as FeatureExtractorLayer
size_ttt = 100

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

utils = Utils()

import utils_lib.feature_extractor_layers as FeatureExtractorLayer
size_ttt = 100

def test_layer(layer):
    time_t = np.array(np.linspace(0,1.0,size_ttt))
    time_t= torch.tensor([time_t]).type(torch.float64)
    result = layer(time_t)
    print(result.shape)
    plt.title("Features extraction by input projection")
    plt.xlabel("input value")
    plt.ylabel("output value.s")
    for i in range(result.shape[2]):
        plt.plot(result[0,:,i],label="neuron "+str(i))
    plt.legend()

# %%
layer = FeatureExtractorLayer.NoneLayer
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_linear.png", dpi=200)
# Out:
# /tmp/ipykernel_7388/61024499.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:230.)
#   time_t= torch.tensor([time_t]).type(torch.float64)
# torch.Size([1, 100, 1])

# %%
#layer = utils.all_feature_extractor[167]["feature_layer"]
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,1.0,0.0,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.gaussian_base
layer = layer(size_ttt,4,1.0,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_gaussian.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.gaussian_dense_acti_base
layer = layer(size_ttt,4,0.01,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_gaussian_learned.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.triangle_activation_1
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_learned.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.D_FLF_cos
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_dflf.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.triangular_cosinus
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_dflf.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.D_FLF_cos
layer = layer(size_ttt,3,"cpu",True)
test_layer(layer)
layer = FeatureExtractorLayer.triangular_cosinus
layer = layer(size_ttt,3,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_tlf.png", dpi=200)
# Out:
# torch.Size([1, 100, 3])
# torch.Size([1, 100, 3])

# %%
layer = FeatureExtractorLayer.triangular_sinus
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_tlf.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.mix_final_1
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_mix_triangular_1.png", dpi=200)
# Out:
# torch.Size([1, 100, 5])

# %%
layer = FeatureExtractorLayer.mix_final_2
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_mix_triangular_2.png", dpi=200)
# Out:
# torch.Size([1, 100, 9])

# %%
layer = FeatureExtractorLayer.mix_final_3
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_mix_triangular_3.png", dpi=200)
# Out:
# torch.Size([1, 100, 17])

# %%
plt.figure(1)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,2,1.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_order_1.png", dpi=200)

plt.figure(2)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,1.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_order_2.png", dpi=200)

plt.figure(3)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,8,1.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_order_3.png", dpi=200)
# Out:
# torch.Size([1, 100, 2])
# torch.Size([1, 100, 4])
# torch.Size([1, 100, 8])

# %%
plt.figure(1)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,1.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_var_1.png", dpi=200)

plt.figure(2)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,2.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_var_2.png", dpi=200)

plt.figure(3)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,4.0,0.0,"cpu",True)
test_layer(layer)
#layer = FeatureExtractorLayer.triangular_base_custom
#layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
#test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_var_3.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])
# torch.Size([1, 100, 4])
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,2.0,0.0,"cpu",True)
test_layer(layer)
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,6,2.0,0.0,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/mi_triangular_full_2.png", dpi=200)

# %%
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,1.0,0.0,"cpu",True)
test_layer(layer)

layer = FeatureExtractorLayer.gaussian_base
layer = layer(size_ttt,4,1.0,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_gaussian_vs_traingular.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.triangular_base_custom
layer = layer(size_ttt,4,1.0,0.0,"cpu",True)
test_layer(layer)

layer = FeatureExtractorLayer.triangle_activation_1
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_triangular_fixed_learned.png", dpi=200)
# Out:
# torch.Size([1, 100, 4])
# torch.Size([1, 100, 4])

# %%
layer = FeatureExtractorLayer.angular_1
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_angular_1.png", dpi=200)
# Out:
# torch.Size([1, 100, 3])

# %%
layer = FeatureExtractorLayer.angular_2
layer = layer(size_ttt,4,"cpu",True)
test_layer(layer)
plt.savefig("./images/layer_plot/projection_angular_2.png", dpi=200)
# Out:
# torch.Size([1, 100, 3])
